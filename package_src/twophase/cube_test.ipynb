# %%
import torch
import numpy as np
import twophase.coord as coord
import twophase.cubie as cubie
import torch.nn as nn
import torch.optim as optim
import pickle
import matplotlib.pyplot as plt

dict = {11.0 : 0, 10.0 : 0, 9.0 : 0, 8.0 : 0, 7.0 : 0, 6.0 : 0, 5.0 : 0, 4.0 : 0}

def generate_data(num_samples):
    # Initialize lists to store the values
    co_values, eo_values, ud_slice_values, N_values = [], [], [], []

    for _ in range(num_samples):
        cube = cubie.CubieCube()
        cube.randomize()

        # Get values for co, eo, and ud_slice
        co, eo, ud_slice = cube.get_twist(), cube.get_flip(), cube.get_slice()
        co_values.append(co)
        eo_values.append(eo)
        ud_slice_values.append(ud_slice)

        # Get the depth for phase 1 (N value)
        N = coord.CoordCube(cube).get_depth_phase1()
        N_values.append(N)
        dict[N] += 1

    # Convert lists to numpy arrays and then to PyTorch tensors
    X = np.column_stack([co_values, eo_values, ud_slice_values])
    N = np.array(N_values)

    return torch.tensor(X, dtype=torch.float32), torch.tensor(N, dtype=torch.float32).view(-1, 1)

# Generate training and test datasets
while dict[11.0] < 1000 or dict[10.0] < 1000 or dict[9.0] < 1000 or dict[8.0] < 1000 or dict[7.0] < 1000 or dict[6.0] < 1000 or dict[5.0] < 1000 or dict[4.0] < 1000:
    train_X, train_Y = generate_data(10)
test_X, test_Y = generate_data(3000)     # 2000 test samples
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/lyce/miniconda3/envs/thesis_test/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_14752/4159035443.py", line 39, in <module>
#     generate_data(100)
#   File "/tmp/ipykernel_14752/4159035443.py", line 18, in generate_data
#     cube.randomize()
#   File "/home/lyce/miniconda3/envs/thesis_test/lib/python3.11/site-packages/twophase/cubie.py", line 499, in randomize
#     p = self.edge_parity()
#         ^^^^^^^^^^^^^^^^^^
#   File "/home/lyce/miniconda3/envs/thesis_test/lib/python3.11/site-packages/twophase/cubie.py", line -1, in edge_parity
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/lyce/miniconda3/envs/thesis_test/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2120, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lyce/miniconda3/envs/thesis_test/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lyce/miniconda3/envs/thesis_test/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lyce/miniconda3/envs/thesis_test/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lyce/miniconda3/envs/thesis_test/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1088, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lyce/miniconda3/envs/thesis_test/lib/python3.11/site-packages/IPython/core/ultratb.py", line 970, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#     ^^^^^^^^^^^^^^^^
#   File "/home/lyce/miniconda3/envs/thesis_test/lib/python3.11/site-packages/IPython/core/ultratb.py", line 792, in lines
#     return self._sd.lines
#            ^^^^^^^^^^^^^^
#   File "/home/lyce/miniconda3/envs/thesis_test/lib/python3.11/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/home/lyce/miniconda3/envs/thesis_test/lib/python3.11/site-packages/stack_data/core.py", line 734, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/home/lyce/miniconda3/envs/thesis_test/lib/python3.11/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/home/lyce/miniconda3/envs/thesis_test/lib/python3.11/site-packages/stack_data/core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "/home/lyce/miniconda3/envs/thesis_test/lib/python3.11/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/home/lyce/miniconda3/envs/thesis_test/lib/python3.11/site-packages/stack_data/core.py", line 660, in executing_piece
#     return only(
#            ^^^^^
#   File "/home/lyce/miniconda3/envs/thesis_test/lib/python3.11/site-packages/executing/executing.py", line 190, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
from torch.utils.data import TensorDataset, DataLoader

# Create TensorDatasets for training and testing
train_dataset = TensorDataset(train_X, train_Y)
test_dataset = TensorDataset(test_X, test_Y)

# Create DataLoaders for training and testing
train_loader = DataLoader(dataset=train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=64)

dict = {}
for i in train_Y:
    if i.item() not in dict:
        dict[i.item()] = 1
    else:
        dict[i.item()] += 1
print(dict)
# Out:
# {10.0: 270106, 9.0: 185233, 8.0: 28266, 11.0: 13394, 7.0: 2733, 6.0: 242, 5.0: 25, 4.0: 1}

# %%
# Define the MLP model
class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(3, 40),  # Input layer with 3 inputs (x, y, z)
            nn.ReLU(),         # Activation function
            nn.Linear(40, 100),
            nn.ReLU(),         # Activation function
            nn.Linear(100, 100),
            nn.ReLU(),         # Activation function
            nn.Linear(100, 40),
            nn.ReLU(),         # Activation function
            nn.Linear(40, 1)   # Output layer with 1 output (n)
        )

    def forward(self, x):
        return self.layers(x)

# Initialize the model
model = MLP()

# Define the optimizer and loss function
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.MSELoss()

# Set matplotlib to interactive mode
plt.ion()

# Initialize the plot
fig, ax = plt.subplots(figsize=(10, 6))
train_losses = []

# Training loop
num_epochs = 10000  # Adjust this as needed
for epoch in range(num_epochs):
    total_loss = 0.0
    for inputs, targets in train_loader:
        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, targets)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    avg_loss = total_loss / len(train_loader)
    train_losses.append(avg_loss)

    # Update the plot
    ax.clear()
    ax.plot(train_losses, label='Training Loss')
    ax.set_xlabel('Epochs')
    ax.set_ylabel('Loss')
    ax.set_title('Training Loss over Epochs')
    ax.legend()
    fig.canvas.draw()
    fig.canvas.flush_events()

    # Optional: print epoch number and loss
    print(f'Epoch [{epoch + 1}/{num_epochs}], Average Loss: {avg_loss:.4f}')

# Turn off interactive mode
plt.ioff()
plt.show()
# Out:
# Epoch [1/10000], Average Loss: 150.2567
# Epoch [2/10000], Average Loss: 13.6221
# Epoch [3/10000], Average Loss: 7.7523
# Epoch [4/10000], Average Loss: 6.5544
# Epoch [5/10000], Average Loss: 6.1715
# Epoch [6/10000], Average Loss: 6.0217
# Epoch [7/10000], Average Loss: 5.9447
# Epoch [8/10000], Average Loss: 6.0966
# Epoch [9/10000], Average Loss: 5.9768
# Epoch [10/10000], Average Loss: 6.0508
# Epoch [11/10000], Average Loss: 5.9944
# Epoch [12/10000], Average Loss: 6.0729
# Epoch [13/10000], Average Loss: 6.0299
# Epoch [14/10000], Average Loss: 6.1389
# Epoch [15/10000], Average Loss: 5.9466
# Epoch [16/10000], Average Loss: 5.9290
# Epoch [17/10000], Average Loss: 5.8091
# Epoch [18/10000], Average Loss: 5.8021
# Epoch [19/10000], Average Loss: 5.7257
# Epoch [20/10000], Average Loss: 5.7478
# Epoch [21/10000], Average Loss: 5.7041
# Epoch [22/10000], Average Loss: 5.8686
# Epoch [23/10000], Average Loss: 5.6069
# Epoch [24/10000], Average Loss: 5.5938
# Epoch [25/10000], Average Loss: 5.6495
# Epoch [26/10000], Average Loss: 5.6011
# Epoch [27/10000], Average Loss: 5.5812
# Epoch [28/10000], Average Loss: 5.5488
# Epoch [29/10000], Average Loss: 5.5854
# Epoch [30/10000], Average Loss: 5.5817
# Epoch [31/10000], Average Loss: 5.6186
# Epoch [32/10000], Average Loss: 5.5359
# Epoch [33/10000], Average Loss: 5.4905
# Epoch [34/10000], Average Loss: 5.4438
# Epoch [35/10000], Average Loss: 5.6251
# Epoch [36/10000], Average Loss: 5.5789
# Epoch [37/10000], Average Loss: 5.4611
# Epoch [38/10000], Average Loss: 5.3930
# Epoch [39/10000], Average Loss: 5.4572
# Epoch [40/10000], Average Loss: 5.4867
# Epoch [41/10000], Average Loss: 5.4274
# Epoch [42/10000], Average Loss: 5.3490
# Epoch [43/10000], Average Loss: 5.3893
# Epoch [44/10000], Average Loss: 5.4060
# Epoch [45/10000], Average Loss: 5.2836
# Epoch [46/10000], Average Loss: 5.2843
# Epoch [47/10000], Average Loss: 5.3170
# Epoch [48/10000], Average Loss: 5.2837
# Epoch [49/10000], Average Loss: 5.1906
# Epoch [50/10000], Average Loss: 5.2568
# Epoch [51/10000], Average Loss: 5.5651
# Epoch [52/10000], Average Loss: 5.3894
# Epoch [53/10000], Average Loss: 5.1022
# Epoch [54/10000], Average Loss: 5.1801
# Epoch [55/10000], Average Loss: 5.0681
# Epoch [56/10000], Average Loss: 4.9921
# Epoch [57/10000], Average Loss: 4.9619
# Epoch [58/10000], Average Loss: 4.8951
# Epoch [59/10000], Average Loss: 4.9938
# Epoch [60/10000], Average Loss: 4.8597
# Epoch [61/10000], Average Loss: 4.8839
# Epoch [62/10000], Average Loss: 4.9928
# Epoch [63/10000], Average Loss: 5.0866
# Epoch [64/10000], Average Loss: 4.8189
# Epoch [65/10000], Average Loss: 4.8480
# Epoch [405/10000], Average Loss: 0.4475
# Epoch [406/10000], Average Loss: 0.4160
# Epoch [407/10000], Average Loss: 0.4200
# Epoch [408/10000], Average Loss: 0.4242
# Epoch [409/10000], Average Loss: 0.4386
# Epoch [410/10000], Average Loss: 0.4335
# Epoch [411/10000], Average Loss: 0.4447
# Epoch [412/10000], Average Loss: 0.4375
# Epoch [413/10000], Average Loss: 0.4295
# Epoch [414/10000], Average Loss: 0.4103
# Epoch [415/10000], Average Loss: 0.4293
# Epoch [416/10000], Average Loss: 0.4313
# Epoch [417/10000], Average Loss: 0.4392
# Epoch [418/10000], Average Loss: 0.4301
# Epoch [419/10000], Average Loss: 0.4156
# Epoch [420/10000], Average Loss: 0.4165
# Epoch [421/10000], Average Loss: 0.4233
# Epoch [422/10000], Average Loss: 0.4172
# Epoch [423/10000], Average Loss: 0.4545
# Epoch [424/10000], Average Loss: 0.4544
# Epoch [425/10000], Average Loss: 0.4553
# Epoch [426/10000], Average Loss: 0.4116
# Epoch [427/10000], Average Loss: 0.4198
# Epoch [428/10000], Average Loss: 0.4178
# Epoch [429/10000], Average Loss: 0.4308
# Epoch [430/10000], Average Loss: 0.4513
# Epoch [431/10000], Average Loss: 0.4204
# Epoch [432/10000], Average Loss: 0.4332
# Epoch [433/10000], Average Loss: 0.4296
# Epoch [434/10000], Average Loss: 0.4209
# Epoch [435/10000], Average Loss: 0.4109
# Epoch [436/10000], Average Loss: 0.4235
# Epoch [437/10000], Average Loss: 0.4236
# Epoch [438/10000], Average Loss: 0.4365
# Epoch [439/10000], Average Loss: 0.4318
# Epoch [440/10000], Average Loss: 0.4223
# Epoch [441/10000], Average Loss: 0.4326
# Epoch [442/10000], Average Loss: 0.4465
# Epoch [443/10000], Average Loss: 0.4195
# Epoch [444/10000], Average Loss: 0.4206
# Epoch [445/10000], Average Loss: 0.4144
# Epoch [446/10000], Average Loss: 0.4437
# Epoch [447/10000], Average Loss: 0.4557
# Epoch [448/10000], Average Loss: 0.4173
# Epoch [449/10000], Average Loss: 0.4369
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /mnt/e/programming/RubiksCube-TwophaseSolver/package_src/twophase/cube_test.ipynb Cell 3 line 4
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/mnt/e/programming/RubiksCube-TwophaseSolver/package_src/twophase/cube_test.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=37'>38</a> for inputs, targets in train_loader:
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/mnt/e/programming/RubiksCube-TwophaseSolver/package_src/twophase/cube_test.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=38'>39</a>     # Forward pass
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/mnt/e/programming/RubiksCube-TwophaseSolver/package_src/twophase/cube_test.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=39'>40</a>     outputs = model(inputs)
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/mnt/e/programming/RubiksCube-TwophaseSolver/package_src/twophase/cube_test.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=40'>41</a>     loss = criterion(outputs, targets)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/mnt/e/programming/RubiksCube-TwophaseSolver/package_src/twophase/cube_test.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=42'>43</a>     # Backward and optimize
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/mnt/e/programming/RubiksCube-TwophaseSolver/package_src/twophase/cube_test.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=43'>44</a>     optimizer.zero_grad()
#
# File ~/miniconda3/envs/thesis_test/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/thesis_test/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/envs/thesis_test/lib/python3.11/site-packages/torch/nn/modules/loss.py:535, in MSELoss.forward(self, input, target)
#     534 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 535     return F.mse_loss(input, target, reduction=self.reduction)
#
# File ~/miniconda3/envs/thesis_test/lib/python3.11/site-packages/torch/nn/functional.py:3329, in mse_loss(input, target, size_average, reduce, reduction)
#    3326     reduction = _Reduction.legacy_get_string(size_average, reduce)
#    3328 expanded_input, expanded_target = torch.broadcast_tensors(input, target)
# -> 3329 return torch._C._nn.mse_loss(expanded_input, expanded_target, _Reduction.get_enum(reduction))
#
# KeyboardInterrupt:

# %%
model.eval()  # Set the model to evaluation mode
total_loss = 0.0

with torch.no_grad():
    for inputs, targets in test_loader:
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        total_loss += loss.item()

average_loss = total_loss / len(test_loader)
print(f'Average Test Loss: {average_loss:.4f}')
# Out:
# Average Test Loss: 0.8227

# %%
pickle.dump(model, open("model_test.pickle", "wb"))
